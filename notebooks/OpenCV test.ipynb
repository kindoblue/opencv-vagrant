# %% [markdown]
# ## OpenCV demo
#
# This notebook is provided to test if OpenCV works

# %%
# Python 3
# %matplotlib inline
import matplotlib.image as mpimg
from matplotlib import pyplot as plt

image = mpimg.imread('images/road.jpg')
plt.imshow(image)

# %%
import cv2

gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,100,300)
cdst = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)

plt.imshow(cdst)

# %%
import numpy as np

lines = cv2.HoughLines(edges, 1, np.pi/180.0, 140, np.array([]), 0, 0)
if lines is not None:
   a,b,c = lines.shape
   for i in range(a):
      rho = lines[i][0][0]
      theta = lines[i][0][1]
      a = np.cos(theta)
      b = np.sin(theta)
      x0, y0 = a*rho, b*rho
      pt1 = ( int(x0+1000*(-b)), int(y0+1000*(a)) )
      pt2 = ( int(x0-1000*(-b)), int(y0-1000*(a)) )
      cv2.line(image, pt1, pt2, (0, 0, 255), 2, cv2.LINE_AA)

plt.imshow(image)
